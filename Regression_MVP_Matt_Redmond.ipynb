# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Analysis of ratebeer.com using rating as the x correlating with score as the y.
#
# There is a high degree of correlation between rating and score of individual beers on ratebeer.com.
#
# However, this result is expected.  It's possible that both score and rate are possible targets and the other columns are better possible x's.
